# %%
text_file = open("7_input.txt","r")
data = text_file.split('\n')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-1e6b969785fb> in <module>()
#       1 text_file = open("7_input.txt","r")
# ----> 2 data = text_file.split('\n')
#
# AttributeError: '_io.TextIOWrapper' object has no attribute 'split'

# %%
import re

with open("7_input.txt", "r") as txtfile:
    data = txtfile.read().strip().split('\n')

# %%
data
# Out:
# ['gbyvdfh (155) -> xqmnq, iyoqt, dimle',
#  'oweiea (97)',
#  'szhxrs (14)',
#  'pjvwsiw (23)',
#  'ycbok (193) -> xibkhsl, futjpq',
#  'wtqnsfh (32)',
#  'jyphghz (5573) -> tuxkm, gcprg, aabvhmt',
#  'fznumf (62)',
#  'kogwes (98)',
#  'sirhaf (57)',
#  'rhnaxsw (42)',
#  'kdqyfds (26)',
#  'tcklgm (62)',
#  'ijeid (142) -> ehjhf, xwdoa',
#  'tqtxfhm (1895) -> qpayfin, kecxvp, uoolai',
#  'gwdydcb (54)',
#  'npjfimt (99) -> qzyvb, dzewqbg, gvsuwlg, gjobtb',
#  'qapbaz (645) -> gyvdr, qdywe, mrgsrr, oeyouc',
#  'ikplxqu (2287) -> grlhmxk, fgspffp, cqfxi',
#  'jczdsk (188) -> gofnx, xvybzq',
#  'mrovove (51)',
#  'giyxwy (83)',
#  'bydzvyp (16)',
#  'itfdh (309) -> oyhly, kshpdif',
#  'pxmnf (256) -> dzqjyp, newtdcb',
#  'xwdoa (89)',
#  'iekxhkq (8)',
#  'mumya (92) -> pqzpiv, uxvcxh',
#  'papkps (57)',
#  'vmuqhd (53)',
#  'ufeocln (239) -> airdbn, xzdshuy, mizef',
#  'mwurel (40)',
#  'unxmdz (93)',
#  'tplns (47)',
#  'gmlan (93) -> waxhr, soplysp',
#  'ntnsu (90)',
# ...

# %%
txtfile
# Out:
# <_io.TextIOWrapper name='7_input.txt' mode='r' encoding='UTF-8'>

# %%
import re

with open("7_input.txt", "r") as txtfile:
    for line in txtfile:
        print(line)

# %%
text_file = open("7_input.txt","r")
lines = text_file.readlines()
lines
# Out:
# ['gbyvdfh (155) -> xqmnq, iyoqt, dimle\n',
#  'oweiea (97)\n',
#  'szhxrs (14)\n',
#  'pjvwsiw (23)\n',
#  'ycbok (193) -> xibkhsl, futjpq\n',
#  'wtqnsfh (32)\n',
#  'jyphghz (5573) -> tuxkm, gcprg, aabvhmt\n',
#  'fznumf (62)\n',
#  'kogwes (98)\n',
#  'sirhaf (57)\n',
#  'rhnaxsw (42)\n',
#  'kdqyfds (26)\n',
#  'tcklgm (62)\n',
#  'ijeid (142) -> ehjhf, xwdoa\n',
#  'tqtxfhm (1895) -> qpayfin, kecxvp, uoolai\n',
#  'gwdydcb (54)\n',
#  'npjfimt (99) -> qzyvb, dzewqbg, gvsuwlg, gjobtb\n',
#  'qapbaz (645) -> gyvdr, qdywe, mrgsrr, oeyouc\n',
#  'ikplxqu (2287) -> grlhmxk, fgspffp, cqfxi\n',
#  'jczdsk (188) -> gofnx, xvybzq\n',
#  'mrovove (51)\n',
#  'giyxwy (83)\n',
#  'bydzvyp (16)\n',
#  'itfdh (309) -> oyhly, kshpdif\n',
#  'pxmnf (256) -> dzqjyp, newtdcb\n',
#  'xwdoa (89)\n',
#  'iekxhkq (8)\n',
#  'mumya (92) -> pqzpiv, uxvcxh\n',
#  'papkps (57)\n',
#  'vmuqhd (53)\n',
#  'ufeocln (239) -> airdbn, xzdshuy, mizef\n',
#  'mwurel (40)\n',
#  'unxmdz (93)\n',
# ...

# %%
import re

with open("7_input.txt", "r") as txtfile:
    datas = txtfile.read().strip().split('\n')
    top = ''
    for item in datas:
    
    #inp = open('input_d7.txt','r').readlines()
#["pbga (66)","xhth (57)","ebii (61)","havc (66)","ktlj (57)","fwft (72) -> ktlj, cntj, xhth","qoyq (66)","padx (45) -> pbga, havc, qoyq","tknk (41) -> ugml, padx, fwft","jptl (61)","ugml (68) -> gyxo, ebii, jptl","gyxo (61)","cntj (57)"]


    #top = ''

    #for item in inp:
        if "->" in item:
            items = item.split("->")
            
            print(items)
            name = items[0][0:items[0].index('(')].strip()
            print(name)
            children = [i.strip() for i in items[1].split(',')]
            print(children)
            '''
            children = [i.strip() for i in items[1].split(',')]
            print (top, name, children, top in children)
            if top == '':
                top = name
            if top in children:
                top = name'''

    #print (top)
# Out:
# ['gbyvdfh (155) ', ' xqmnq, iyoqt, dimle']
# gbyvdfh
# ['xqmnq', 'iyoqt', 'dimle']
# ['ycbok (193) ', ' xibkhsl, futjpq']
# ycbok
# ['xibkhsl', 'futjpq']
# ['jyphghz (5573) ', ' tuxkm, gcprg, aabvhmt']
# jyphghz
# ['tuxkm', 'gcprg', 'aabvhmt']
# ['ijeid (142) ', ' ehjhf, xwdoa']
# ijeid
# ['ehjhf', 'xwdoa']
# ['tqtxfhm (1895) ', ' qpayfin, kecxvp, uoolai']
# tqtxfhm
# ['qpayfin', 'kecxvp', 'uoolai']
# ['npjfimt (99) ', ' qzyvb, dzewqbg, gvsuwlg, gjobtb']
# npjfimt
# ['qzyvb', 'dzewqbg', 'gvsuwlg', 'gjobtb']
# ['qapbaz (645) ', ' gyvdr, qdywe, mrgsrr, oeyouc']
# qapbaz
# ['gyvdr', 'qdywe', 'mrgsrr', 'oeyouc']
# ['ikplxqu (2287) ', ' grlhmxk, fgspffp, cqfxi']
# ikplxqu
# ['grlhmxk', 'fgspffp', 'cqfxi']
# ['jczdsk (188) ', ' gofnx, xvybzq']
# jczdsk
# ['gofnx', 'xvybzq']
# ['itfdh (309) ', ' oyhly, kshpdif']
# itfdh
# ['oyhly', 'kshpdif']
# ['pxmnf (256) ', ' dzqjyp, newtdcb']
# pxmnf
# ['dzqjyp', 'newtdcb']
# ['mumya (92) ', ' pqzpiv, uxvcxh']
# mumya
# ['pqzpiv', 'uxvcxh']
# ...

# %%
programs = {'<name>': {'weight': <int>, 'children': []}, ...}
for program, data in dict(programs).items():  
    for child in data.get('children'):
        if child in programs:
            del programs[child]
print(list(programs)[0])
